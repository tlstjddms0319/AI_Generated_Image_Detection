# %% [markdown]
# # 00. 환경 세팅 확인
# - Python / PyTorch / GPU 상태 확인
# - 필수 패키지 import 테스트

# %%
# ============================================================
# 패키지 설치 (최초 1회만 실행, 이후 주석 처리)
# ============================================================
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install grad-cam timm pandas Pillow matplotlib scikit-learn tqdm

# %%
# ============================================================
# 버전 및 GPU 확인
# ============================================================
import sys
import torch
import torchvision

print(f"Python     : {sys.version}")
print(f"PyTorch    : {torch.__version__}")
print(f"Torchvision: {torchvision.__version__}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n사용 디바이스: {device}")

if device.type == "cuda":
    print(f"GPU 이름  : {torch.cuda.get_device_name(0)}")
    vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"VRAM      : {vram:.1f} GB")
else:
    print("⚠️  GPU 없음 — CPU로 진행 (학습 속도 매우 느림)")
# Out:
# Python     : 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]
# PyTorch    : 2.6.0+cu124
# Torchvision: 0.21.0+cu124
#
# 사용 디바이스: cuda
# GPU 이름  : NVIDIA GeForce RTX 4070 SUPER
# VRAM      : 12.9 GB

# %%
# ============================================================
# 필수 패키지 import 테스트
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import roc_auc_score
from pytorch_grad_cam import GradCAM

print("✅ 모든 패키지 import 성공!")
# Out:
# ✅ 모든 패키지 import 성공!
